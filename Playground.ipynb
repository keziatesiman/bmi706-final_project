# %%
import os
import zipfile
import pandas as pd
import numpy as np
import altair as alt
import streamlit as st
from vega_datasets import data
import icd10

# %%
! pip install icd10-cm
# Out:
# Collecting icd10-cm
#   Downloading icd10_cm-0.0.4-py2.py3-none-any.whl (675 kB)
#      |████████████████████████████████| 675 kB 1.9 MB/s eta 0:00:01
# Installing collected packages: icd10-cm
# Successfully installed icd10-cm-0.0.4

# %%
with zipfile.ZipFile("merged_datasets.zip") as myzip:
    no1 = myzip.open("merged_datasets/phase_I_test.csv")
    no2 = myzip.open("merged_datasets/phase_I_valid.csv")
    no3 = myzip.open("merged_datasets/phase_I_train.csv")
    no4 = myzip.open("merged_datasets/phase_II_valid.csv")
    no5 = myzip.open("merged_datasets/phase_II_test.csv")
    no6 = myzip.open("merged_datasets/phase_II_train.csv")
    no7 = myzip.open("merged_datasets/phase_III_valid.csv")
    no8 = myzip.open("merged_datasets/phase_III_test.csv")
    no9 = myzip.open("merged_datasets/phase_III_train.csv")
    
#Now, we can read in the data
df = pd.read_csv(eval('no1'))

for i in range(2,10): 
    df_temp = pd.read_csv(eval('no'+ str(i)))
    df = df.append(df_temp, ignore_index=True)

df.head()
# Out:
# /var/folders/gn/1dwlg7ns6s3d_22hhl8kmrwm0000gn/T/ipykernel_8320/2957319813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# /var/folders/gn/1dwlg7ns6s3d_22hhl8kmrwm0000gn/T/ipykernel_8320/2957319813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# /var/folders/gn/1dwlg7ns6s3d_22hhl8kmrwm0000gn/T/ipykernel_8320/2957319813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# /var/folders/gn/1dwlg7ns6s3d_22hhl8kmrwm0000gn/T/ipykernel_8320/2957319813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# /var/folders/gn/1dwlg7ns6s3d_22hhl8kmrwm0000gn/T/ipykernel_8320/2957319813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# /var/folders/gn/1dwlg7ns6s3d_22hhl8kmrwm0000gn/T/ipykernel_8320/2957319813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# /var/folders/gn/1dwlg7ns6s3d_22hhl8kmrwm0000gn/T/ipykernel_8320/2957319813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# /var/folders/gn/1dwlg7ns6s3d_22hhl8kmrwm0000gn/T/ipykernel_8320/2957319813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
#                file       nct_id     status            phase  \
# 0  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 1  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 2  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 3  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 4  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
#
#                                             diseases  \
# 0  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 1  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 2  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 3  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 4  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
#
#                                             icdcodes  \
# 0  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 1  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 2  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 3  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 4  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
#
#                                         drugs  \
# 0  ['plerixafor', 'plerixafor', 'plerixafor']
# 1  ['plerixafor', 'plerixafor', 'plerixafor']
# 2  ['plerixafor', 'plerixafor', 'plerixafor']
# 3  ['plerixafor', 'plerixafor', 'plerixafor']
# 4  ['plerixafor', 'plerixafor', 'plerixafor']
#
#                                              smiless  \
# 0  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 1  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 2  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 3  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 4  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
#
#                                             criteria  study_date  country  \
# 0  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Belgium
# 1  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Czechia
# 2  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Denmark
# 3  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28   France
# 4  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Germany
#
#    participant_count  outcome
# 0                NaN        1
# 1                NaN        1
# 2                NaN        1
# 3                NaN        1
# 4                NaN        1

# %%
df_merged_grouped3 = df.groupby(['outcome','phase']).agg(trials_count=('nct_id', np.size)).reset_index()
df_merged_grouped3.head()
# Out:
#    outcome            phase  trials_count
# 0        0    early phase 1            45
# 1        0          phase 1          2365
# 2        0  phase 1/phase 2         13986
# 3        0          phase 2        116359
# 4        0  phase 2/phase 3         11612

# %%
chart2 = alt.Chart(df_merged_grouped3).mark_bar().encode(
    x='outcome:N',
    y='trials_count:Q',
    color='outcome:N',
    column='phase'
)
chart2
# Out:
# alt.Chart(...)

# %%
country_df = pd.read_csv('https://raw.githubusercontent.com/hms-dbmi/bmi706-2022/main/cancer_data/country_codes.csv', dtype = {'conuntry-code': str})
country_df = country_df[['Country', 'country-code']]
country_df = country_df.replace('United States of America', 'United States')

country_code_df = pd.merge(df, country_df,  how='left', left_on='country', right_on='Country')
country_code_df.head()
# Out:
#                file       nct_id     status            phase  \
# 0  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 1  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 2  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 3  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 4  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
#
#                                             diseases  \
# 0  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 1  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 2  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 3  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 4  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
#
#                                             icdcodes  \
# 0  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 1  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 2  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 3  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 4  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
#
#                                         drugs  \
# 0  ['plerixafor', 'plerixafor', 'plerixafor']
# 1  ['plerixafor', 'plerixafor', 'plerixafor']
# 2  ['plerixafor', 'plerixafor', 'plerixafor']
# 3  ['plerixafor', 'plerixafor', 'plerixafor']
# 4  ['plerixafor', 'plerixafor', 'plerixafor']
#
#                                              smiless  \
# 0  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 1  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 2  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 3  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 4  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
#
#                                             criteria  study_date  country  \
# 0  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Belgium
# 1  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Czechia
# 2  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Denmark
# 3  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28   France
# 4  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Germany
#
#    participant_count  outcome  Country  country-code
# 0                NaN        1  Belgium          56.0
# 1                NaN        1  Czechia         203.0
# 2                NaN        1  Denmark         208.0
# 3                NaN        1   France         250.0
# 4                NaN        1  Germany         276.0

# %%
df_country_new = country_code_df.groupby(['country','country-code']).agg(trials_count=('nct_id', np.size)).reset_index()

# %%
source = alt.topo_feature(data.world_110m.url, 'countries')

width = 900
height  = 500
project = 'equirectangular'


background = alt.Chart(source
).mark_geoshape(
    fill='#aaa',
    stroke='white'
).properties(
    width=width,
    height=height
).project(project)


base = alt.Chart(source
    ).properties( 
        width=width,
        height=height
    ).project(project
    ).transform_lookup(
        lookup="id",
        from_=alt.LookupData(df_country_new, "country-code", fields =['trials_count', 'country']),
    )



# fix the color schema so that it will not change upon user selection
rate_scale = alt.Scale(domain=[df_country_new['trials_count'].min(), df_country_new['trials_count'].max()])
rate_color = alt.Color(field="trials_count", type="quantitative", scale=rate_scale)
chart_rate = base.mark_geoshape().encode(
    ######################
    # P3.1 map visualization showing the mortality rate
    # add your code here
    ######################
    # P3.3 tooltip
    # add your code here
    color='trials_count:Q',
    tooltip=['trials_count:Q', 'country:N']

    )
background + chart_rate
# Out:
# alt.LayerChart(...)

# %%
country_code_df["year"] = pd.DatetimeIndex(country_code_df["study_date"]).year.astype("float")
df = country_code_df
df.head()
# Out:
#                file       nct_id     status            phase  \
# 0  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 1  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 2  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 3  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 4  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
#
#                                             diseases  \
# 0  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 1  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 2  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 3  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 4  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
#
#                                             icdcodes  \
# 0  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 1  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 2  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 3  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 4  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
#
#                                         drugs  \
# 0  ['plerixafor', 'plerixafor', 'plerixafor']
# 1  ['plerixafor', 'plerixafor', 'plerixafor']
# 2  ['plerixafor', 'plerixafor', 'plerixafor']
# 3  ['plerixafor', 'plerixafor', 'plerixafor']
# 4  ['plerixafor', 'plerixafor', 'plerixafor']
#
#                                              smiless  \
# 0  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 1  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 2  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 3  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 4  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
#
#                                             criteria  study_date  country  \
# 0  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Belgium
# 1  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Czechia
# 2  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Denmark
# 3  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28   France
# 4  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Germany
#
#    participant_count  outcome  Country  country-code    year
# 0                NaN        1  Belgium          56.0  2011.0
# 1                NaN        1  Czechia         203.0  2011.0
# 2                NaN        1  Denmark         208.0  2011.0
# 3                NaN        1   France         250.0  2011.0
# 4                NaN        1  Germany         276.0  2011.0

# %%
subset = df[df['year'].notna()]
subset = subset[subset["year"] <= 2012]

countries = ["Austria","Germany","Iceland","Spain","Sweden","Thailand","Turkey"]
subset = subset[subset["country"].isin(countries)]

# %%
df2 = subset.groupby(['country','country-code','year']).agg(trials_count=('nct_id', np.size)).reset_index()
df2.head()
# Out:
#    country  country-code    year  trials_count
# 0  Austria          40.0  1999.0             4
# 1  Austria          40.0  2000.0             1
# 2  Austria          40.0  2001.0             1
# 3  Austria          40.0  2002.0             5
# 4  Austria          40.0  2003.0            73

# %%
chart4 = alt.Chart(df2).mark_line().encode(
    x=alt.X("year:O"),
    y=alt.Y("trials_count"),
    color="country"
)
chart4
# Out:
# alt.Chart(...)

# %%
df3 = subset.groupby(['outcome','phase']).agg(trials_count=('nct_id', np.size)).reset_index()
df3
# Out:
#    outcome            phase  trials_count
# 0        0          phase 1           107
# 1        0  phase 1/phase 2          1272
# 2        0          phase 2          9064
# 3        0  phase 2/phase 3           836
# 4        0          phase 3         15640
# 5        1          phase 1          1125
# 6        1  phase 1/phase 2           758
# 7        1          phase 2         24693
# 8        1  phase 2/phase 3          1732
# 9        1          phase 3         53805

# %%
select_phase = alt.selection_single(fields=[alt.FieldName("phase")])

chart5_left = alt.Chart(df3).mark_arc().encode(
    theta="sum(trials_count)",
    color="phase",
    opacity=alt.condition(select_phase, alt.value(1), alt.value(0.5)),
).add_selection(select_phase)

chart5_right = alt.Chart(df3).mark_arc().encode(
    theta="trials_count",
    color="outcome:O",
    tooltip=["trials_count","phase"]
).transform_filter(select_phase)

chart5 = alt.hconcat(chart5_left, chart5_right
).resolve_scale(
    color="independent",
    theta="independent"
)
chart5
# Out:
# alt.HConcatChart(...)

# %%
with zipfile.ZipFile("smaller.zip") as myzip:    
    no1 = myzip.open("smaller.csv")

#Now, we can read in the data
df = pd.read_csv(eval('no1'), index_col=0)

# %%
df
# Out:
#                         file       nct_id     status            phase  \
# 0           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 1           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 2           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 3           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 4           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# ...                      ...          ...        ...              ...
# 1352647  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352648  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352649  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352650  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352651  phase_III_train.csv  NCT01097018  completed          phase 3
#
#                                                   diseases  \
# 0        ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 1        ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 2        ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 3        ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 4        ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# ...                                                    ...
# 1352647                              ['treatment outcome']
# 1352648                              ['treatment outcome']
# 1352649                              ['treatment outcome']
# 1352650                              ['treatment outcome']
# 1352651                              ['colorectal cancer']
#
#                                                   icdcodes  \
# 0        ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 1        ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 2        ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 3        ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 4        ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# ...                                                    ...
# 1352647  ["['Z01.12', 'Z92.89', 'Z75.2', 'M27.59', 'Z53...
# 1352648  ["['Z01.12', 'Z92.89', 'Z75.2', 'M27.59', 'Z53...
# 1352649  ["['Z01.12', 'Z92.89', 'Z75.2', 'M27.59', 'Z53...
# 1352650  ["['Z01.12', 'Z92.89', 'Z75.2', 'M27.59', 'Z53...
# 1352651  ["['C05.2', 'C10.0', 'C16.0', 'C16.4', 'C17.0'...
#
#                                                drugs  \
# 0         ['plerixafor', 'plerixafor', 'plerixafor']
# 1         ['plerixafor', 'plerixafor', 'plerixafor']
# 2         ['plerixafor', 'plerixafor', 'plerixafor']
# 3         ['plerixafor', 'plerixafor', 'plerixafor']
# 4         ['plerixafor', 'plerixafor', 'plerixafor']
# ...                                              ...
# 1352647  ['vortioxetine', 'escitalopram', 'placebo']
# 1352648  ['vortioxetine', 'escitalopram', 'placebo']
# 1352649  ['vortioxetine', 'escitalopram', 'placebo']
# 1352650  ['vortioxetine', 'escitalopram', 'placebo']
# 1352651    ['capecitabine', 'perifosine', 'placebo']
#
#                                                    smiless  study_date  \
# 0        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 1        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 2        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 3        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 4        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# ...                                                    ...         ...
# 1352647  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352648  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352649  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352650  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352651  ['[H][N]1([H])[C@@H]2CCCC[C@H]2[N]([H])([H])[P...         NaN
#
#          country  participant_count  outcome
# 0        Belgium                NaN        1
# 1        Czechia                NaN        1
# 2        Denmark                NaN        1
# 3         France                NaN        1
# 4        Germany                NaN        1
# ...          ...                ...      ...
# 1352647   Canada              217.0        1
# 1352648   Canada              207.0        1
# 1352649   Canada              217.0        1
# 1352650   Canada              207.0        1
# 1352651      NaN                NaN        0
#
# [1352652 rows x 12 columns]

# %%
def col_to_list(column):
  """
  String to list of strings for an entire column
  Can be applied to "drugs", "diseases" and "icdcodes"
  """

  def remove_artefacts(entry):

    return "".join([c for c in entry if c not in ["[", "]", "'", "\""]])
  
  column = [remove_artefacts(e) for e in column]
  column = [e.split(", ") for e in column]

  return column


def remove_abbreviations(l):

  return [it.split(sep=" (")[0] for it in l]

# %%
# reformat train, validation and test data, does not work in a for loop
df["drugs"] = col_to_list(df["drugs"])
df["diseases"] = col_to_list(df["diseases"])
df["diseases"] = [remove_abbreviations(l) for l in df["diseases"]]
df["icdcodes"] = col_to_list(df["icdcodes"])

# %%
df
# Out:
#                         file       nct_id     status            phase  \
# 0           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 1           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 2           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 3           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 4           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# ...                      ...          ...        ...              ...
# 1352647  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352648  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352649  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352650  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352651  phase_III_train.csv  NCT01097018  completed          phase 3
#
#                                                   diseases  \
# 0        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 1        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 2        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 3        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 4        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# ...                                                    ...
# 1352647                                [treatment outcome]
# 1352648                                [treatment outcome]
# 1352649                                [treatment outcome]
# 1352650                                [treatment outcome]
# 1352651                                [colorectal cancer]
#
#                                                   icdcodes  \
# 0        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 1        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 2        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 3        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 4        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# ...                                                    ...
# 1352647  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352648  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352649  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352650  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352651  [C05.2, C10.0, C16.0, C16.4, C17.0, C17.1, C17.2]
#
#                                          drugs  \
# 0         [plerixafor, plerixafor, plerixafor]
# 1         [plerixafor, plerixafor, plerixafor]
# 2         [plerixafor, plerixafor, plerixafor]
# 3         [plerixafor, plerixafor, plerixafor]
# 4         [plerixafor, plerixafor, plerixafor]
# ...                                        ...
# 1352647  [vortioxetine, escitalopram, placebo]
# 1352648  [vortioxetine, escitalopram, placebo]
# 1352649  [vortioxetine, escitalopram, placebo]
# 1352650  [vortioxetine, escitalopram, placebo]
# 1352651    [capecitabine, perifosine, placebo]
#
#                                                    smiless  study_date  \
# 0        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 1        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 2        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 3        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 4        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# ...                                                    ...         ...
# 1352647  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352648  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352649  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352650  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352651  ['[H][N]1([H])[C@@H]2CCCC[C@H]2[N]([H])([H])[P...         NaN
#
#          country  participant_count  outcome
# 0        Belgium                NaN        1
# 1        Czechia                NaN        1
# 2        Denmark                NaN        1
# 3         France                NaN        1
# 4        Germany                NaN        1
# ...          ...                ...      ...
# 1352647   Canada              217.0        1
# 1352648   Canada              207.0        1
# 1352649   Canada              217.0        1
# 1352650   Canada              207.0        1
# 1352651      NaN                NaN        0
#
# [1352652 rows x 12 columns]

# %%
def get_desc(x): 
  code = icd10.find(x)
  #print(code)
  desc = ''
  if (code == None):
    desc= 'Other' 
  else: 
    desc =  code.description
  return desc



def get_chapter(x): 
  code = icd10.find(x)
  #print(code)
  desc = 'Other'

  try: 
    desc =  code.chapter
  except Exception: 
    pass 
  return desc



def get_block(x): 
  code = icd10.find(x)
  desc = 'Other'
  try: 
    desc =  code.block
  except Exception: 
    pass 

  return desc


def get_block_desc(x): 
  code = icd10.find(x)
  #print(code)
  desc = 'Other'
  try: 
    desc =  code.block_description
  except Exception: 
    pass 
  return desc

# %%
df['icdcodes_first'] = df['icdcodes'].apply(lambda x: x[0])

# %%
df
# Out:
#                         file       nct_id     status            phase  \
# 0           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 1           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 2           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 3           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 4           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# ...                      ...          ...        ...              ...
# 1352647  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352648  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352649  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352650  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352651  phase_III_train.csv  NCT01097018  completed          phase 3
#
#                                                   diseases  \
# 0        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 1        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 2        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 3        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 4        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# ...                                                    ...
# 1352647                                [treatment outcome]
# 1352648                                [treatment outcome]
# 1352649                                [treatment outcome]
# 1352650                                [treatment outcome]
# 1352651                                [colorectal cancer]
#
#                                                   icdcodes  \
# 0        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 1        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 2        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 3        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 4        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# ...                                                    ...
# 1352647  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352648  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352649  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352650  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352651  [C05.2, C10.0, C16.0, C16.4, C17.0, C17.1, C17.2]
#
#                                          drugs  \
# 0         [plerixafor, plerixafor, plerixafor]
# 1         [plerixafor, plerixafor, plerixafor]
# 2         [plerixafor, plerixafor, plerixafor]
# 3         [plerixafor, plerixafor, plerixafor]
# 4         [plerixafor, plerixafor, plerixafor]
# ...                                        ...
# 1352647  [vortioxetine, escitalopram, placebo]
# 1352648  [vortioxetine, escitalopram, placebo]
# 1352649  [vortioxetine, escitalopram, placebo]
# 1352650  [vortioxetine, escitalopram, placebo]
# 1352651    [capecitabine, perifosine, placebo]
#
#                                                    smiless  study_date  \
# 0        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 1        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 2        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 3        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 4        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# ...                                                    ...         ...
# 1352647  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352648  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352649  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352650  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352651  ['[H][N]1([H])[C@@H]2CCCC[C@H]2[N]([H])([H])[P...         NaN
#
#          country  participant_count  outcome icdcodes_first
# 0        Belgium                NaN        1          C71.7
# 1        Czechia                NaN        1          C71.7
# 2        Denmark                NaN        1          C71.7
# 3         France                NaN        1          C71.7
# 4        Germany                NaN        1          C71.7
# ...          ...                ...      ...            ...
# 1352647   Canada              217.0        1         Z01.12
# 1352648   Canada              207.0        1         Z01.12
# 1352649   Canada              217.0        1         Z01.12
# 1352650   Canada              207.0        1         Z01.12
# 1352651      NaN                NaN        0          C05.2
#
# [1352652 rows x 13 columns]

# %%
df['description'] = df['icdcodes_first'].apply(get_desc)
df['chapter'] = df['icdcodes_first'].apply(get_chapter)
df['block'] = df['icdcodes_first'].apply(get_block)
df['block_desc'] = df['icdcodes_first'].apply(get_block_desc)

# %%
df
# Out:
#                         file       nct_id     status            phase  \
# 0           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 1           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 2           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 3           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 4           phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# ...                      ...          ...        ...              ...
# 1352647  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352648  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352649  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352650  phase_III_train.csv  NCT01364649  completed          phase 3
# 1352651  phase_III_train.csv  NCT01097018  completed          phase 3
#
#                                                   diseases  \
# 0        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 1        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 2        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 3        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 4        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# ...                                                    ...
# 1352647                                [treatment outcome]
# 1352648                                [treatment outcome]
# 1352649                                [treatment outcome]
# 1352650                                [treatment outcome]
# 1352651                                [colorectal cancer]
#
#                                                   icdcodes  \
# 0        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 1        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 2        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 3        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 4        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# ...                                                    ...
# 1352647  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352648  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352649  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352650  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352651  [C05.2, C10.0, C16.0, C16.4, C17.0, C17.1, C17.2]
#
#                                          drugs  \
# 0         [plerixafor, plerixafor, plerixafor]
# 1         [plerixafor, plerixafor, plerixafor]
# 2         [plerixafor, plerixafor, plerixafor]
# 3         [plerixafor, plerixafor, plerixafor]
# 4         [plerixafor, plerixafor, plerixafor]
# ...                                        ...
# 1352647  [vortioxetine, escitalopram, placebo]
# 1352648  [vortioxetine, escitalopram, placebo]
# 1352649  [vortioxetine, escitalopram, placebo]
# 1352650  [vortioxetine, escitalopram, placebo]
# 1352651    [capecitabine, perifosine, placebo]
#
#                                                    smiless  study_date  \
# 0        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 1        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 2        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 3        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 4        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# ...                                                    ...         ...
# 1352647  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352648  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352649  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352650  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352651  ['[H][N]1([H])[C@@H]2CCCC[C@H]2[N]([H])([H])[P...         NaN
#
#          country  participant_count  outcome icdcodes_first  \
# 0        Belgium                NaN        1          C71.7
# 1        Czechia                NaN        1          C71.7
# 2        Denmark                NaN        1          C71.7
# 3         France                NaN        1          C71.7
# 4        Germany                NaN        1          C71.7
# ...          ...                ...      ...            ...
# 1352647   Canada              217.0        1         Z01.12
# 1352648   Canada              207.0        1         Z01.12
# 1352649   Canada              217.0        1         Z01.12
# 1352650   Canada              207.0        1         Z01.12
# 1352651      NaN                NaN        0          C05.2
#
#                                               description chapter    block  \
# 0                        Malignant neoplasm of brain stem    None     None
# 1                        Malignant neoplasm of brain stem    None     None
# 2                        Malignant neoplasm of brain stem    None     None
# 3                        Malignant neoplasm of brain stem    None     None
# 4                        Malignant neoplasm of brain stem    None     None
# ...                                                   ...     ...      ...
# 1352647  Encounter for hearing conservation and treatment     XXI  Z00-Z99
# 1352648  Encounter for hearing conservation and treatment     XXI  Z00-Z99
# 1352649  Encounter for hearing conservation and treatment     XXI  Z00-Z99
# 1352650  Encounter for hearing conservation and treatment     XXI  Z00-Z99
# 1352651                       Malignant neoplasm of uvula      II  C00-D48
#
#                                                 block_desc
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 1352647  Factors influencing health status and contact ...
# 1352648  Factors influencing health status and contact ...
# 1352649  Factors influencing health status and contact ...
# 1352650  Factors influencing health status and contact ...
# 1352651                                          Neoplasms
#
# [1352652 rows x 17 columns]

# %%
code = icd10.find("C71.7")
print(code.description)         # Acute bronchitis due to Mycoplasma pneumoniae
if code.billable:
    print(code, "is billable")  # J20.0 is billable

print(code.chapter)             # X
print(code.block)               # J00-J99
print(code.block_description)   # Diseases of the respiratory system
# Out:
# Malignant neoplasm of brain stem
# C71.7 is billable
# None
# None
# None

# %%
df.columns
# Out:
# Index(['file', 'nct_id', 'status', 'phase', 'diseases', 'icdcodes', 'drugs',
#        'smiless', 'study_date', 'country', 'participant_count', 'outcome',
#        'icdcodes_first', 'description', 'chapter', 'block', 'block_desc'],
#       dtype='object')

# %%
df = df[['nct_id', 'status', 'phase', 'diseases', 'icdcodes', 'drugs',
       'smiless', 'study_date', 'country', 'participant_count', 'outcome',
       'icdcodes_first', 'description', 'chapter', 'block', 'block_desc']]

# %%
df
# Out:
#               nct_id     status            phase  \
# 0        NCT01288573  completed  phase 1/phase 2
# 1        NCT01288573  completed  phase 1/phase 2
# 2        NCT01288573  completed  phase 1/phase 2
# 3        NCT01288573  completed  phase 1/phase 2
# 4        NCT01288573  completed  phase 1/phase 2
# ...              ...        ...              ...
# 1352647  NCT01364649  completed          phase 3
# 1352648  NCT01364649  completed          phase 3
# 1352649  NCT01364649  completed          phase 3
# 1352650  NCT01364649  completed          phase 3
# 1352651  NCT01097018  completed          phase 3
#
#                                                   diseases  \
# 0        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 1        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 2        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 3        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# 4        [ewings sarcoma/soft tissue sarcoma, neuroblas...
# ...                                                    ...
# 1352647                                [treatment outcome]
# 1352648                                [treatment outcome]
# 1352649                                [treatment outcome]
# 1352650                                [treatment outcome]
# 1352651                                [colorectal cancer]
#
#                                                   icdcodes  \
# 0        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 1        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 2        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 3        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# 4        [C71.7, C71.9, C79.31, D33.0, D33.1, D33.2, D4...
# ...                                                    ...
# 1352647  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352648  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352649  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352650  [Z01.12, Z92.89, Z75.2, M27.59, Z53.9, Z91.19,...
# 1352651  [C05.2, C10.0, C16.0, C16.4, C17.0, C17.1, C17.2]
#
#                                          drugs  \
# 0         [plerixafor, plerixafor, plerixafor]
# 1         [plerixafor, plerixafor, plerixafor]
# 2         [plerixafor, plerixafor, plerixafor]
# 3         [plerixafor, plerixafor, plerixafor]
# 4         [plerixafor, plerixafor, plerixafor]
# ...                                        ...
# 1352647  [vortioxetine, escitalopram, placebo]
# 1352648  [vortioxetine, escitalopram, placebo]
# 1352649  [vortioxetine, escitalopram, placebo]
# 1352650  [vortioxetine, escitalopram, placebo]
# 1352651    [capecitabine, perifosine, placebo]
#
#                                                    smiless  study_date  \
# 0        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 1        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 2        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 3        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# 4        ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...  2011-01-28
# ...                                                    ...         ...
# 1352647  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352648  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352649  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352650  ['CC1=CC=C(SC2=CC=CC=C2N2CCNCC2)C(C)=C1', 'CN(...  2011-05-31
# 1352651  ['[H][N]1([H])[C@@H]2CCCC[C@H]2[N]([H])([H])[P...         NaN
#
#          country  participant_count  outcome icdcodes_first  \
# 0        Belgium                NaN        1          C71.7
# 1        Czechia                NaN        1          C71.7
# 2        Denmark                NaN        1          C71.7
# 3         France                NaN        1          C71.7
# 4        Germany                NaN        1          C71.7
# ...          ...                ...      ...            ...
# 1352647   Canada              217.0        1         Z01.12
# 1352648   Canada              207.0        1         Z01.12
# 1352649   Canada              217.0        1         Z01.12
# 1352650   Canada              207.0        1         Z01.12
# 1352651      NaN                NaN        0          C05.2
#
#                                               description chapter    block  \
# 0                        Malignant neoplasm of brain stem    None     None
# 1                        Malignant neoplasm of brain stem    None     None
# 2                        Malignant neoplasm of brain stem    None     None
# 3                        Malignant neoplasm of brain stem    None     None
# 4                        Malignant neoplasm of brain stem    None     None
# ...                                                   ...     ...      ...
# 1352647  Encounter for hearing conservation and treatment     XXI  Z00-Z99
# 1352648  Encounter for hearing conservation and treatment     XXI  Z00-Z99
# 1352649  Encounter for hearing conservation and treatment     XXI  Z00-Z99
# 1352650  Encounter for hearing conservation and treatment     XXI  Z00-Z99
# 1352651                       Malignant neoplasm of uvula      II  C00-D48
#
#                                                 block_desc
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 1352647  Factors influencing health status and contact ...
# 1352648  Factors influencing health status and contact ...
# 1352649  Factors influencing health status and contact ...
# 1352650  Factors influencing health status and contact ...
# 1352651                                          Neoplasms
#
# [1352652 rows x 16 columns]

# %%
df.to_csv('full_df.csv')

# %%
import os
import zipfile
import pandas as pd
import numpy as np
import altair as alt
import streamlit as st
from vega_datasets import data

# %%
with zipfile.ZipFile("full_df.zip") as myzip:    
    no1 = myzip.open("full_df.csv")

# %%
#Now, we can read in the data
df = pd.read_csv(eval('no1'))

df_merged_grouped = df.groupby(['phase','status']).agg(trials_count=('nct_id', np.size)).reset_index()

df_merged_grouped3 = df.groupby(['outcome','phase']).agg(trials_count=('nct_id', np.size)).reset_index()

country_df = pd.read_csv('https://raw.githubusercontent.com/hms-dbmi/bmi706-2022/main/cancer_data/country_codes.csv', dtype = {'country-code': str})
country_df = country_df[['Country', 'country-code']]
country_df = country_df.replace('United States of America', 'United States')

country_code_df = pd.merge(df, country_df,  how='left', left_on='country', right_on='Country')
country_code_df["year"] = pd.DatetimeIndex(country_code_df["study_date"]).year.astype("float")
df = country_code_df

df_country_new = country_code_df.groupby(['country','country-code']).agg(trials_count=('nct_id', np.size)).reset_index()
###
SFbyCountry = country_code_df.groupby(['country','country-code','outcome']).agg(trials_count=('nct_id', np.size)).reset_index()

countries = ["Austria","Germany","Iceland","Spain","Sweden","Thailand","Turkey"]
SFbyCountry = SFbyCountry[SFbyCountry["country"].isin(countries)]
#####

success_count = df[df.outcome == 1]
success_count = success_count[success_count.participant_count  > 0]

fail_count = df[df.outcome == 0]
fail_count = fail_count[fail_count.participant_count  > 0]
# Out:
# 2022-05-02 00:49:20.458 INFO    numexpr.utils: NumExpr defaulting to 8 threads.

# %%
chart1 = alt.Chart(df_merged_grouped).mark_bar().encode(
    x=alt.X('sum(trials_count)', stack="normalize", axis=alt.Axis(format='%', title='percentage')),
    y='phase',
    color='status'
)

chart1
# Out:
# alt.Chart(...)

# %%
chart2 = alt.Chart(SFbyCountry).mark_bar().encode(
    x=alt.X('sum(trials_count)', stack="normalize", axis=alt.Axis(format='%', title='percentage')),
    y='country',
    color=alt.Color('outcome', legend=None)
)
chart2
# Out:
# alt.Chart(...)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# nct_id                    0
# status                    0
# phase                     0
# diseases                  0
# icdcodes                  0
# drugs                     0
# smiless                   0
# study_date              737
# country                4042
# participant_count     11850
# outcome                   0
# icdcodes_first            0
# description               0
# chapter              137300
# block                137300
# block_desc           137300
# Country              103913
# country-code         103913
# year                    737
# dtype: int64
