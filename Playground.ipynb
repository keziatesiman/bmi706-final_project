# %%
import pandas as pd
import os
from zipfile import ZipFile, Path

# %%
path = "../../merged_datasets"
dir_list = os.listdir(path)
dir_list
# Out:
# ['phase_I_test.csv',
#  'phase_I_valid.csv',
#  'phase_III_train.csv',
#  'phase_II_valid.csv',
#  'phase_III_test.csv',
#  'phase_II_train.csv',
#  'phase_III_valid.csv',
#  'phase_II_test.csv',
#  'phase_I_train.csv']

# %%
with ZipFile("merged_datasets.zip") as myzip:
    
    no1 = myzip.open("merged_datasets/phase_I_test.csv")
    no2 = myzip.open("merged_datasets/phase_I_valid.csv")
    no3 = myzip.open("merged_datasets/phase_I_train.csv")
    no4 = myzip.open("merged_datasets/phase_II_valid.csv")
    no5 = myzip.open("merged_datasets/phase_II_test.csv")
    no6 = myzip.open("merged_datasets/phase_II_train.csv")
    no7 = myzip.open("merged_datasets/phase_III_valid.csv")
    no8 = myzip.open("merged_datasets/phase_III_test.csv")
    no9 = myzip.open("merged_datasets/phase_III_train.csv")
    
    

#Now, we can read in the data
df = pd.read_csv(eval('no1'))

for i in range(2,10): 
    df_temp = pd.read_csv(eval('no'+ str(i)))
    df = df.append(df_temp, ignore_index=True)


df.head()
# Out:
#                file       nct_id     status            phase  \
# 0  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 1  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 2  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 3  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
# 4  phase_I_test.csv  NCT01288573  completed  phase 1/phase 2
#
#                                             diseases  \
# 0  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 1  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 2  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 3  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
# 4  ["ewing's sarcoma/soft tissue sarcoma", 'neuro...
#
#                                             icdcodes  \
# 0  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 1  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 2  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 3  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
# 4  ["['C71.7', 'C71.9', 'C79.31', 'D33.0', 'D33.1...
#
#                                         drugs  \
# 0  ['plerixafor', 'plerixafor', 'plerixafor']
# 1  ['plerixafor', 'plerixafor', 'plerixafor']
# 2  ['plerixafor', 'plerixafor', 'plerixafor']
# 3  ['plerixafor', 'plerixafor', 'plerixafor']
# 4  ['plerixafor', 'plerixafor', 'plerixafor']
#
#                                              smiless  \
# 0  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 1  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 2  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 3  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
# 4  ['C(N1CCCNCCNCCCNCC1)C1=CC=C(CN2CCCNCCNCCCNCC2...
#
#                                             criteria  study_date  country  \
# 0  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Belgium
# 1  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Czechia
# 2  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Denmark
# 3  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28   France
# 4  \n        Inclusion Criteria:\n\n          -  ...  2011-01-28  Germany
#
#    participant_count  outcome
# 0                NaN        1
# 1                NaN        1
# 2                NaN        1
# 3                NaN        1
# 4                NaN        1
